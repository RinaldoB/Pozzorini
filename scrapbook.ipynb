# %%
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ls
# Out:
# Generate_Stims.ipynb  noise 30s.txt                             README.md
# I_noise_info.txt      noise 60s 10kHz sampling freq.txt         recordings/
# I_noise_info.txt~     Noise_stimuli.zip                         stim_files/
# noise 10s.txt         OU_Process_Generator_fixed_std_dev.ipynb  Untitled.ipynb

# %% [markdown]
# ## 0th rec - VC

# %%
stim = fromfile('stim_files/I_noise_test_30s.tpl', dtype='f4')[:200000]

# %%
amp_in = loadtxt('recordings/noise_30s.txt', skiprows=1)

# %%
stim.shape, amp_in.shape
# Out:
# ((200000,), (200000,))

# %%
plot(stim)
plot(amp_in)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## 1st rec - CC

# %%
ls recordings/Noise_Test_2_20kHz_30s_2016_06_21/
# Out:
# noise_test_2_2016_06_21.dat
# Noise_Test_2_CurrentIn_(input)_20kHz_30s_2016_06_21.txt
# Noise_Test_2_VoltageIn_(output)_20kHz_30s_2016_06_21.txt

# %%
maxidx = 10000
dt = 1/20000.; time = arange(maxidx)*dt

stim    = fromfile('stim_files/I_noise_test_30s.tpl', dtype='f4')[:maxidx]*1e3
#mV

amp_in  = loadtxt('recordings/Noise_Test_2_20kHz_30s_2016_06_21/Noise_Test_2_CurrentIn_(input)_20kHz_30s_2016_06_21.txt', skiprows=1)[:maxidx]*1e12
#pA

amp_out = loadtxt('recordings/Noise_Test_2_20kHz_30s_2016_06_21/Noise_Test_2_VoltageIn_(output)_20kHz_30s_2016_06_21.txt', skiprows=1)[:maxidx]*1e3
#mV

# %%
subplot(3,1,1)
plot(time, stim)
subplot(3,1,2)
plot(time, amp_in)
subplot(3,1,3)
plot(time, amp_out)
# Out:
# <img src="data:image/png;base64,...">

# %%
amp_in.mean(), amp_out.mean()
# Out:
# (376.72710676999998, -15.254356680000001)
